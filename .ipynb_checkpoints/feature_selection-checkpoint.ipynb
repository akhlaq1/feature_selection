# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.feature_selection import SelectKBest, chi2

# %%
df = pd.read_excel('data/rpsp1.xlsx', sheet_name='Sheet1')
df
# Out:
#                   choice  Gender  Income  Driving-years  Purpose  Duration  \
# 0    normal parking slot       2       3              1        3         3
# 1    shared parking slot       2       4              2        1         4
# 2    normal parking slot       2       4              1        1         3
# 3    shared parking slot       2       2              1        1         1
# 4    shared parking slot       1       2              1        3         4
# ..                   ...     ...     ...            ...      ...       ...
# 243  normal parking slot       1       1              2        1         1
# 244  shared parking slot       2       3              1        3         3
# 245  shared parking slot       1       2              1        3         3
# 246  normal parking slot       2       3              1        4         2
# 247  shared parking slot       1       1              3        1         4
#
#      Fee  Walking-distance  Rent-or-not   Parking-time-limited  \
# 0      2                 1             1                     3
# 1      3                 2             2                     3
# 2      3                 1             1                     3
# 3      2                 2             3                     4
# 4      4                 2             1                     3
# ..   ...               ...           ...                   ...
# 243    4                 2             1                     2
# 244    4                 2             3                     2
# 245    4                 1             1                     4
# 246    4                 2             1                     3
# 247    3                 2             3                     2
#
#       Information of free parking is not released timely  Vehicle-safety  \
# 0                                                    2                 4
# 1                                                    4                 3
# 2                                                    4                 4
# 3                                                    4                 3
# 4                                                    2                 2
# ..                                                 ...               ...
# 243                                                  4                 3
# 244                                                  2                 3
# 245                                                  2                 1
# 246                                                  3                 3
# 247                                                  3                 3
#
#      Others  total
# 0         2     11
# 1         3     13
# 2         3     14
# 3         2     13
# 4         1      8
# ..      ...    ...
# 243       2     11
# 244       3     10
# 245       1      8
# 246       2     11
# 247       2     10
#
# [248 rows x 14 columns]

# %%
dummies = pd.get_dummies(df['choice'], prefix='choice', drop_first=False)
df = pd.concat([df, dummies], axis=1)
df = df.drop(['choice'], axis=1)

# %%
df
# Out:
#      Gender  Income  Driving-years  Purpose  Duration  Fee  Walking-distance  \
# 0         2       3              1        3         3    2                 1
# 1         2       4              2        1         4    3                 2
# 2         2       4              1        1         3    3                 1
# 3         2       2              1        1         1    2                 2
# 4         1       2              1        3         4    4                 2
# ..      ...     ...            ...      ...       ...  ...               ...
# 243       1       1              2        1         1    4                 2
# 244       2       3              1        3         3    4                 2
# 245       1       2              1        3         3    4                 1
# 246       2       3              1        4         2    4                 2
# 247       1       1              3        1         4    3                 2
#
#      Rent-or-not   Parking-time-limited  \
# 0               1                     3
# 1               2                     3
# 2               1                     3
# 3               3                     4
# 4               1                     3
# ..            ...                   ...
# 243             1                     2
# 244             3                     2
# 245             1                     4
# 246             1                     3
# 247             3                     2
#
#       Information of free parking is not released timely  Vehicle-safety  \
# 0                                                    2                 4
# 1                                                    4                 3
# 2                                                    4                 4
# 3                                                    4                 3
# 4                                                    2                 2
# ..                                                 ...               ...
# 243                                                  4                 3
# 244                                                  2                 3
# 245                                                  2                 1
# 246                                                  3                 3
# 247                                                  3                 3
#
#      Others  total  choice_normal parking slot  choice_shared parking slot
# 0         2     11                           1                           0
# 1         3     13                           0                           1
# 2         3     14                           1                           0
# 3         2     13                           0                           1
# 4         1      8                           0                           1
# ..      ...    ...                         ...                         ...
# 243       2     11                           1                           0
# 244       3     10                           0                           1
# 245       1      8                           0                           1
# 246       2     11                           1                           0
# 247       2     10                           0                           1
#
# [248 rows x 15 columns]

# %%
X = df.drop(['choice_normal parking slot','choice_shared parking slot'],axis=1)
y = df[['choice_shared parking slot']].copy()

# %%
# Out:
# 'Gender'

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

y1 = np.array(y)
y1 = y1.reshape(y1.shape[0])
y1.shape

rfe = RFE(logreg, 4)
rfe = rfe.fit(X,y1)
print(rfe.support_)
print(rfe.ranking_)

for i,bol in enumerate(rfe.support_):
    if bol:
        print(X.columns[i])
# Out:
# [ True False False False  True False  True False  True False False False
#  False]
# [ 1  8  2  4  1  9  1  5  1 10  3  7  6]
# Gender
# Duration
# Walking-distance
# Parking-time-limited

# %%
df.boxplot('Duration','choice',rot = 30,figsize=(5,6))

# %%
# Out:
# (248,)

# %%
plt.figure(figsize=(30, 15))
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.savefig("heatmap.jpg")

# %%
plt.figure(figsize=(30, 15))
sns.boxplot(x="variable", y="value", data=pd.melt(df))
plt.savefig('combine_boxplot_without_time.jpg')

plt.show()

# %%
# Step 1 - Make a scatter plot with square markers, set column names as labels
plt.figure(figsize=(30, 15))
def heatmap(x, y, size):
    fig, ax = plt.subplots()
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num), # Use mapping for x
        y=y.map(y_to_num), # Use mapping for y
        s=size * size_scale, # Vector of square sizes, proportional to size parameter
        marker='s' # Use square as scatterplot marker
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)
    
corr = df.corr()
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)
plt.savefig("box_heatmap.png")

# %%
df
# Out:
#                   choice  Gender  Income  Driving-years  Purpose  Duration  \
# 0    normal parking slot       2       3              1        3         3
# 1    shared parking slot       2       4              2        1         4
# 2    normal parking slot       2       4              1        1         3
# 3    shared parking slot       2       2              1        1         1
# 4    shared parking slot       1       2              1        3         4
# ..                   ...     ...     ...            ...      ...       ...
# 243  normal parking slot       1       1              2        1         1
# 244  shared parking slot       2       3              1        3         3
# 245  shared parking slot       1       2              1        3         3
# 246  normal parking slot       2       3              1        4         2
# 247  shared parking slot       1       1              3        1         4
#
#      Fee  Walking-distance  Rent-or-not   Parking-time-limited  \
# 0      2                 1             1                     3
# 1      3                 2             2                     3
# 2      3                 1             1                     3
# 3      2                 2             3                     4
# 4      4                 2             1                     3
# ..   ...               ...           ...                   ...
# 243    4                 2             1                     2
# 244    4                 2             3                     2
# 245    4                 1             1                     4
# 246    4                 2             1                     3
# 247    3                 2             3                     2
#
#       Information of free parking is not released timely  Vehicle-safety  \
# 0                                                    2                 4
# 1                                                    4                 3
# 2                                                    4                 4
# 3                                                    4                 3
# 4                                                    2                 2
# ..                                                 ...               ...
# 243                                                  4                 3
# 244                                                  2                 3
# 245                                                  2                 1
# 246                                                  3                 3
# 247                                                  3                 3
#
#      Others  total
# 0         2     11
# 1         3     13
# 2         3     14
# 3         2     13
# 4         1      8
# ..      ...    ...
# 243       2     11
# 244       3     10
# 245       1      8
# 246       2     11
# 247       2     10
#
# [248 rows x 14 columns]

# %% [markdown]
# # Spearman's Rank Correlation

# %%
corr = df.corr(method='spearman')
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']

table = pd.pivot_table(corr, values='value', index=['x'],
                    columns=['y'], aggfunc=np.sum)

# %%
table[['choice_normal parking slot','choice_shared parking slot']]
# Out:
# y                                                   choice_normal parking slot  \
# x
# Driving-years                                                        -0.014478
# Duration                                                              0.083226
# Fee                                                                   0.007643
# Gender                                                                0.051443
# Income                                                                0.048638
# Others                                                               -0.010202
# Parking-time-limited                                                 -0.059089
# Purpose                                                               0.026537
# Rent-or-not                                                           0.019481
# Vehicle-safety                                                        0.051446
# Walking-distance                                                     -0.162607
# choice_normal parking slot                                            1.000000
# choice_shared parking slot                                           -1.000000
# total                                                                -0.015676
#  Information of free parking is not released ti...                   -0.047821
#
# y                                                   choice_shared parking slot
# x
# Driving-years                                                         0.014478
# Duration                                                             -0.083226
# Fee                                                                  -0.007643
# Gender                                                               -0.051443
# Income                                                               -0.048638
# Others                                                                0.010202
# Parking-time-limited                                                  0.059089
# Purpose                                                              -0.026537
# Rent-or-not                                                          -0.019481
# Vehicle-safety                                                       -0.051446
# Walking-distance                                                      0.162607
# choice_normal parking slot                                           -1.000000
# choice_shared parking slot                                            1.000000
# total                                                                 0.015676
#  Information of free parking is not released ti...                    0.047821

# %% [markdown]
# # Chi-Square Test

# %%
def check_categorical_dependency(crosstab_table, confidence_interval):
    stat, p, dof, expected = stats.chi2_contingency(crosstab_table)
    print ("Chi-Square Statistic value = {}".format(stat))
    print ("P - Value = {}".format(p))
    alpha = 1.0 - confidence_interval
    if p <= alpha:
        print('Dependent (reject H0)')
    else:
        print('Independent (fail to reject H0)')
    return expected

# %%
for i in X.columns:
    print(i)
    cross_table = pd.crosstab(df[i], df['choice_shared parking slot'], 
    print("\n")                                  margins=True)
    print(cross_table)
    
    print("\n")
    
    check_categorical_dependency(cross_table, 0.8)
    print("\n \n")
# Out:
# Gender
# choice_shared parking slot   0    1  All
# Gender
# 1                           21  103  124
# 2                           26   98  124
# All                         47  201  248
# Chi-Square Statistic value = 0.6562930030697576
# P - Value = 0.9566074697279146
# Independent (fail to reject H0)
#
#
#
# Income
# choice_shared parking slot   0    1  All
# Income
# 1                            6   30   36
# 2                            8   51   59
# 3                           20   64   84
# 4                            9   40   49
# 5                            4   16   20
# All                         47  201  248
# Chi-Square Statistic value = 2.5550409036775052
# P - Value = 0.9900491331960529
# Independent (fail to reject H0)
#
#
#
# Driving-years
# choice_shared parking slot   0    1  All
# Driving-years
# 1                           31  125  156
# 2                           10   59   69
# 3                            6   17   23
# All                         47  201  248
# Chi-Square Statistic value = 1.7414811660051694
# P - Value = 0.9418741333674835
# Independent (fail to reject H0)
#
#
#
# Purpose
# choice_shared parking slot   0    1  All
# Purpose
# 1                           20  105  125
# 2                            9   25   34
# 3                           15   39   54
# 4                            3   25   28
# 5                            0    7    7
# All                         47  201  248
# Chi-Square Statistic value = 7.572863852855633
# P - Value = 0.6704797106527934
# Independent (fail to reject H0)
#
#
#
# Duration
# choice_shared parking slot   0    1  All
# Duration
# 1                            5   49   54
# 2                            8   32   40
# 3                           19   62   81
# 4                           15   49   64
# 5                            0    9    9
# All                         47  201  248
# Chi-Square Statistic value = 7.344542587822643
# P - Value = 0.6925666247181512
# Independent (fail to reject H0)
#
#
#
# Fee
# choice_shared parking slot   0    1  All
# Fee
# 1                            2    7    9
# 2                            6   38   44
# 3                           18   68   86
# 4                           17   61   78
# 5                            4   27   31
# All                         47  201  248
# Chi-Square Statistic value = 2.2400248725327927
# P - Value = 0.9941475045318041
# Independent (fail to reject H0)
#
#
#
# Walking-distance
# choice_shared parking slot   0    1  All
# Walking-distance
# 1                           15   45   60
# 2                           30  112  142
# 3                            2   33   35
# 4                            0   11   11
# All                         47  201  248
# Chi-Square Statistic value = 8.431365838728786
# P - Value = 0.3925059522935292
# Independent (fail to reject H0)
#
#
#
# Rent-or-not
# choice_shared parking slot   0    1  All
# Rent-or-not
# 1                           37  164  201
# 2                            8   21   29
# 3                            2   16   18
# All                         47  201  248
# Chi-Square Statistic value = 2.166708921588829
# P - Value = 0.9037454978876087
# Independent (fail to reject H0)
#
#
#
# Parking-time-limited
# choice_shared parking slot   0    1  All
# Parking-time-limited
# 1                            1    6    7
# 2                           15   49   64
# 3                           23  103  126
# 4                            8   43   51
# All                         47  201  248
# Chi-Square Statistic value = 1.3316344356450456
# P - Value = 0.9951633281770823
# Independent (fail to reject H0)
#
#
#
#  Information of free parking is not released timely
# choice_shared parking slot                           0    1  All
#  Information of free parking is not released ti...
# 1                                                    2    5    7
# 2                                                   13   51   64
# 3                                                   16   66   82
# 4                                                   16   79   95
# All                                                 47  201  248
# Chi-Square Statistic value = 0.7909098548600623
# P - Value = 0.9992557688491439
# Independent (fail to reject H0)
#
#
#
# Vehicle-safety
# choice_shared parking slot   0    1  All
# Vehicle-safety
# 1                            4   12   16
# 2                           11   62   73
# 3                           15   70   85
# 4                           17   57   74
# All                         47  201  248
# Chi-Square Statistic value = 1.9709692217399026
# P - Value = 0.9818889418844415
# Independent (fail to reject H0)
#
#
#
# Others
# choice_shared parking slot   0    1  All
# Others
# 1                            8   40   48
# 2                           30  115  145
# 3                            8   35   43
# 4                            1   11   12
# All                         47  201  248
# Chi-Square Statistic value = 1.3325361906648001
# P - Value = 0.9951519216135053
# Independent (fail to reject H0)
#
#
#
# total
# choice_shared parking slot   0    1  All
# total
# 4                            1    2    3
# 6                            0    1    1
# 7                            1    2    3
# 8                            3   13   16
# 9                            6   19   25
# 10                           5   50   55
# 11                          18   37   55
# 12                           3   35   38
# 13                           6   22   28
# 14                           4   17   21
# 15                           0    3    3
# All                         47  201  248
# Chi-Square Statistic value = 15.571796525581687
# P - Value = 0.836554433558954
# Independent (fail to reject H0)

# %%
exp_table_1 = check_categorical_dependency(gender_table, 0.95)
# Out:
# Chi-Square Statistic value = 0.6562930030697576
# P - Value = 0.9566074697279146
# Independent (fail to reject H0)

# %% [markdown]
# # Feature Selection using Chi-Square

# %%
X_new = SelectKBest(chi2, k=4).fit_transform(X, y)

# %%
X_new.shape
# Out:
# (248, 4)

# %%
pd.crosstab(np.squeeze(X_new[:,0]), np.squeeze(y))
# Out:
# choice_shared parking slot   0   1
# row_0
# 1                            6  30
# 2                            8  51
# 3                           20  64
# 4                            9  40
# 5                            4  16
